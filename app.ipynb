# %%
import streamlit as st
import pandas as pd
import numpy as np
import plotly.graph_objects as go

# --- PAGE CONFIGURATION (Browser Tab) ---
st.set_page_config(
    page_title="RCP | Repayment Capacity Passport",
    page_icon="🛡️",
    layout="centered",
    initial_sidebar_state="collapsed"
)

# --- CUSTOM CSS FOR "BANK SAFE" STYLING ---
# Hiding Streamlit branding to look like a proprietary tool
hide_streamlit_style = """
            <style>
            #MainMenu {visibility: hidden;}
            footer {visibility: hidden;}
            header {visibility: hidden;}
            .stApp {background-color: #FAFAFA;}
            h1, h2, h3 {font-family: 'Helvetica', sans-serif; color: #0f172a;}
            </style>
            """
st.markdown(hide_streamlit_style, unsafe_allow_html=True)

# --- SECTION 1: HERO (The Promise) ---
st.title("Repayment Capacity Passport (RCP)")
st.caption("INSTITUTIONAL RISK ANALYTICS | B2B ONLY")
st.markdown("---")

col1, col2 = st.columns([2, 1])

with col1:
    st.subheader("The Blind Spot in Portfolio Risk")
    st.write(
        """
        Credit Bureau data lags by 30-45 days. In that window, risk accumulates unseen.
        
        **RCP is a behavior-based analytics layer** that sits inside your bank's firewall. 
        It detects repayment velocity changes and utilization stress in real-time—weeks before a bureau score drop.
        """
    )
    st.info("Designed for: Risk Officers, Portfolio Managers, and Credit Policy Teams.")

with col2:
    st.markdown("### Core Capabilities")
    st.markdown("✅ **Early Stress Detection**")
    st.markdown("✅ **Upgrade Readiness Filters**")
    st.markdown("✅ **RBI-Compliant (No Black Box)**")
    st.markdown("✅ **Zero-Knowledge Data Privacy**")

st.markdown("---")

# --- SECTION 2: THE "RESEARCH" DEMO (Building Trust) ---
# We simulate a chart to prove you understand the math.
st.subheader("Methodology: The Latency Gap")
st.write("Visualizing how RCP detects stress before traditional scoring models.")

# --- MOCK DATA GENERATION ---
# Create a timeline where a borrower gets stressed at Day 30
days = list(range(1, 61))
# Bureau Score stays flat until Day 45 (Reporting lag)
bureau_score = [750] * 45 + [680] * 15
# RCP Signal reacts at Day 32 (Behavioral change detection)
rcp_signal = [100] * 30 + [85, 70, 60, 50, 45, 40, 40, 40] + [40] * 22
rcp_signal = rcp_signal[:60] # Ensure length match

df = pd.DataFrame({
    "Day": days,
    "Bureau Score (Traditional)": bureau_score,
    "RCP Signal (Behavioral)": rcp_signal
})

# Scaling for visualization comparison
# (Normalizing to display on same chart structure)
df["Bureau Score (Traditional)"] = df["Bureau Score (Traditional)"] / 7.5

# Plotting
fig = go.Figure()
fig.add_trace(go.Scatter(x=df['Day'], y=df['Bureau Score (Traditional)'],
                    mode='lines', name='Bureau Score (Lagged)', line=dict(color='gray', width=2, dash='dash')))
fig.add_trace(go.Scatter(x=df['Day'], y=df['RCP Signal (Behavioral)'],
                    mode='lines', name='RCP Signal (Real-Time)', line=dict(color='#d90429', width=4)))

fig.update_layout(
    title="Comparative Signal Latency",
    xaxis_title="Days in Portfolio",
    yaxis_title="Health Indicator (Normalized)",
    template="simple_white",
    height=400,
    legend=dict(yanchor="top", y=0.99, xanchor="left", x=0.01)
)

st.plotly_chart(fig, use_container_width=True)
st.caption("Figure 1: RCP identifies stress behaviors (Red) 14 days before Bureau reporting cycles (Grey).")

st.markdown("---")

# --- SECTION 3: COMPLIANCE & SAFETY ---
st.subheader("Regulatory & Deployment Stance")

c1, c2, c3 = st.columns(3)

with c1:
    st.markdown("#### 🔒 1. Data Sovereignty")
    st.write("RCP is deployed as a Docker container within your infrastructure. Customer PII never leaves your bank.")

with c2:
    st.markdown("#### 📜 2. Deterministic Logic")
    st.write("No 'Black Box' AI. All signals are based on auditable, behavior-based heuristics (Velocity & Elasticity).")

with c3:
    st.markdown("#### 🛡️ 3. Conservative")
    st.write("RCP is a supplementary signal. It does not auto-reject or auto-price. Final decisions remain with the bank.")

st.markdown("---")

# --- SECTION 4: CONTACT / CALL TO ACTION ---
st.subheader("Pilot Program Inquiry")
st.write("RCP is currently in closed beta for select institutional partners.")

contact_form = """
<form action="https://formsubmit.co/YOUR_EMAIL_HERE" method="POST">
     <input type="hidden" name="_captcha" value="false">
     <input type="text" name="name" placeholder="Name" required style="width: 100%; padding: 8px; margin-bottom: 10px; border: 1px solid #ccc; border-radius: 4px;">
     <input type="email" name="email" placeholder="Bank / Institution Email" required style="width: 100%; padding: 8px; margin-bottom: 10px; border: 1px solid #ccc; border-radius: 4px;">
     <button type="submit" style="background-color: #0f172a; color: white; padding: 10px 20px; border: none; border-radius: 4px; cursor: pointer;">Request Whitepaper</button>
</form>
"""
st.markdown(contact_form, unsafe_allow_html=True)

st.markdown("<br><br>", unsafe_allow_html=True)
st.markdown(
    "<div style='text-align: center; color: grey; font-size: 12px;'>© 2024 RCP Analytics. For Institutional Use Only. Not for Retail Customers.</div>", 
    unsafe_allow_html=True
)
# Out:
# 2026-02-03 16:04:07.415 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-03 16:04:07.420 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-03 16:04:09.872
# ...
#   command:
#
#     streamlit run D:\New folder\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-03 16:04:09.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-03 16:04:09.876 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-02-03 16:04:09.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...
